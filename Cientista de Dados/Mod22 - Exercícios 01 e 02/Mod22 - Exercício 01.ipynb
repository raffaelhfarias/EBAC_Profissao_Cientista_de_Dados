# %% [markdown]
# # Tarefa 01
#
# - Leia os enunciados com atenção
# - Saiba que pode haver mais de uma resposta correta
# - Insira novas células de código sempre que achar necessário
# - Em caso de dúvidas, procure os monitores
# - Divirta-se :)

# %%
from pandas_datareader import data as web

import plotly.express as px
from plotly import graph_objects

import pandas as pd
import numpy as np

# %% [markdown]
# #### 1. Baixando dados de ativos
#     1. Baixe os dados de três ativos da sua escolha do Yahoo Finance, correspondente a um período de pelo menos 2 anos até a data mais recente.
#     2. Salve esses dados para que você possa utilizá-los na próxima tarefa.

# %%
# %%time
ativos = ['ITUB3.SA', 'PETR4.SA', 'ABEV3.SA']
dt_ini = '01/01/2019'

yf = web.get_data_yahoo(ativos, start=dt_ini)
yf.head(2)
# Out:
# CPU times: total: 156 ms
# Wall time: 4.77 s
# Attributes  Adj Close                            Close                      \
# Symbols      ITUB3.SA   PETR4.SA   ABEV3.SA   ITUB3.SA   PETR4.SA ABEV3.SA
# Date
# 2019-01-02  27.604595  12.641031  14.685471  31.959999  24.059999    16.15
# 2019-01-03  27.855064  12.951015  14.849148  32.250000  24.650000    16.33
#
# Attributes       High                              Low                      \
# Symbols      ITUB3.SA   PETR4.SA   ABEV3.SA   ITUB3.SA   PETR4.SA ABEV3.SA
# Date
# 2019-01-02  32.270000  24.200001  16.299999  30.049999  22.280001    15.40
# 2019-01-03  32.299999  24.820000  16.330000  31.309999  23.799999    15.89
#
# Attributes       Open                        Volume
# Symbols      ITUB3.SA   PETR4.SA ABEV3.SA  ITUB3.SA     PETR4.SA    ABEV3.SA
# Date
# 2019-01-02  30.049999  22.549999    15.40  976900.0  104534800.0  18692900.0
# 2019-01-03  31.309999  23.959999    16.01  283000.0   95206400.0  22739200.0

# %%
yf.to_csv('yf.csv')

# %% [markdown]
# #### 2. Observando a volatilidade dentro do dia
# 1. Calcule a amplitude de variação do valor do ativo dentro do dia. Essa amplitude você pode calcular com um comando simples de adicionar uma coluna no Pandas: (valor máximo - valor mínimo).
# 2. Monte um gráfico de linha mostrando a variação dessa amplitude ao longo do período coletado, por ativo.
# 3. Veja se consegue identificar que ativo apresentou maior volatilidade.

# %%
amp = yf['High']-yf['Low']
amp.head(2)
# Out:
# Symbols     ITUB3.SA  PETR4.SA  ABEV3.SA
# Date
# 2019-01-02  2.220001      1.92      0.90
# 2019-01-03  0.990000      1.02      0.44

# %%
amp_vertical = amp.stack().reset_index()
amp_vertical.columns = ['data', 'ativo', 'amplitude']

amp_vertical.head()
# Out:
#         data     ativo  amplitude
# 0 2019-01-02  ITUB3.SA   2.220001
# 1 2019-01-02  PETR4.SA   1.920000
# 2 2019-01-02  ABEV3.SA   0.900000
# 3 2019-01-03  ITUB3.SA   0.990000
# 4 2019-01-03  PETR4.SA   1.020000

# %%
fig = px.line(amp_vertical, x="data", y="amplitude", color='ativo', template='plotly_white')
fig.show()
# Out:
# <div>                            <div id="79bf716f-9cf6-4e77-9ee1-302f55ab998a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("79bf716f-9cf6-4e77-9ee1-302f55ab998a")) {                    Plotly.newPlot(                        "79bf716f-9cf6-4e77-9ee1-302f55ab998a",                        [{"hovertemplate":"ativo=ITUB3.SA<br>data=%{x}<br>amplitude=%{y}<extra></extra>","legendgroup":"ITUB3.SA","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"ITUB3.SA","showlegend":true,"x":["2019-01-02T00:00:00","2019-01-03T00:00:00","2019-01-04T00:00:00","2019-01-07T00:00:00","2019-01-08T00:00:00","2019-01-09T00:00:00","2019-01-10T00:00:00","2019-01-11T00:00:00","2019-01-14T00:00:00","2019-01-15T00:00:00","2019-01-16T00:
# ...

# %% [markdown]
# Analisando o gráfico PETR4.SA aparenta ter maior volatilidade, principalmente no último ano.
